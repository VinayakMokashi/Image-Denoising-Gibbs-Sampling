# %% [markdown]
# # Image Denoising using Gibbs Sampling
#
# This notebook is a thin, interactive demo on top of [`denoise.py`](denoise.py), which holds the actual implementation (vectorised red/black Gibbs sampling on an Ising / pairwise-MRF model).
#
# Model energy for binary images `Y, X` in `{-1, +1}`:
#
# $$E(Y, X) = -\eta \sum_i Y_i X_i \; - \; \beta \sum_{\langle i,j \rangle} Y_i Y_j$$
#
# with single-pixel posterior $P(Y_i = +1 \mid \cdot) = \sigma(2w)$, $w = \eta X_i + \beta \sum_{\text{neighbours}} Y_j$.
#
# For batch use / your own images, the command line is usually easier — see `README.md`.

# %%
import numpy as np
import matplotlib.pyplot as plt

from denoise import (
    load_binary_image, gibbs_denoise, add_salt_pepper, binary_to_uint8,
)

# %matplotlib inline

# %% [markdown]
# ## 1. Load the noisy image

# %%
X = load_binary_image('Noisy.png', threshold='auto')  # -> {-1, +1} array
print('shape:', X.shape)

plt.figure(figsize=(8, 4))
plt.imshow(binary_to_uint8(X), cmap='gray', vmin=0, vmax=255)
plt.title('Noisy input'); plt.axis('off'); plt.show()

# %% [markdown]
# ## 2. Run Gibbs sampling
#
# `eta` weights the data term (trust in the observation); `beta` weights smoothness (neighbour agreement). Increase `beta` for stronger denoising.

# %%
denoised, posterior, energies = gibbs_denoise(
    X, eta=1.0, beta=1.0, burn_in=100, samples=1000, seed=0, verbose=False,
)

# %% [markdown]
# ## 3. Show the result and the energy convergence

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
axes[0].imshow(binary_to_uint8(X), cmap='gray', vmin=0, vmax=255)
axes[0].set_title('Noisy input'); axes[0].axis('off')
axes[1].imshow(binary_to_uint8(denoised), cmap='gray', vmin=0, vmax=255)
axes[1].set_title('Denoised'); axes[1].axis('off')
plt.tight_layout(); plt.show()

# %%
steps = np.array([e[0] for e in energies])
vals  = np.array([e[1] for e in energies])
phase = np.array([e[2] for e in energies])
plt.figure(figsize=(8, 5))
plt.plot(steps[phase == 'B'], vals[phase == 'B'], 'r', label='burn-in')
plt.plot(steps[phase == 'S'], vals[phase == 'S'], 'b', label='sampling')
plt.title('Energy convergence'); plt.xlabel('iteration'); plt.ylabel('energy')
plt.legend(); plt.show()

# %% [markdown]
# ## 4. Try it on your own image
#
# The model is for **bilevel** images. Take any clean black-and-white-ish image, corrupt it, then denoise it. Here we round-trip the clean `Denoised.png` through 15% noise.

# %%
clean = load_binary_image('Denoised.png', threshold='auto')
noisy = add_salt_pepper(clean, prob=0.15, rng=np.random.default_rng(1))
recovered, _, _ = gibbs_denoise(noisy, beta=1.0, samples=500, seed=0, verbose=False)

fig, axes = plt.subplots(1, 3, figsize=(16, 5))
for ax, img, title in zip(
    axes, [clean, noisy, recovered], ['Clean', 'Noisy (15%)', 'Recovered']):
    ax.imshow(binary_to_uint8(img), cmap='gray', vmin=0, vmax=255)
    ax.set_title(title); ax.axis('off')
plt.tight_layout(); plt.show()
